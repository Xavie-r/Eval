# %% [markdown]
# # Evaluation Boucle While et For

# %% [markdown]
# ## Tables de multiplication

# %% [markdown]
# /1
# Ecrire un programme dont le résultat donne ce qui suit :
#
# Donner un Nombre : 5
#     5
#     10
#     15
#     20
#     25
#     30
#     35
#     40
#     45
#     50

# %% [markdown]
# /2
# Ecrire un programme dont le résultat donne ce qui suit :
#
# Donner un nombre : 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %% [markdown]
# ## Moyenne

# %% [markdown]
# /3
# Ecrire un programme qui demande 5 notes sur 20 à l'utilisateur
# et calcul la moyenne  des notes.
#
# Entrez une note  : 12
# Entrez une note  : 10
# Entrez une note  : 11
# Entrez une note  : 13
# Entrez une note  : 10
# La moyenne vaut  : 11

# %% [markdown]
# /4
# Ecrire un programme qui demande des notes sur 20 jusqu'à ce que l'utilisateur entre le nombre 100
# ce qui entraine le calcul de la moyenne de toutes les notes.
#
# Entrez une note ou fin pour terminer : 12
# Entrez une note ou fin pour terminer : 10
# Entrez une note ou fin pour terminer : 11
# Entrez une note ou fin pour terminer : 13
# Entrez une note ou fin pour terminer : 10
# Entrez une note ou fin pour terminer : 100
# La moyenne vaut  : 11

# %% [markdown]
# /5
# Si l'utilisateur tape 0, alors afficher les tables de multiplication de 1 à 10.
